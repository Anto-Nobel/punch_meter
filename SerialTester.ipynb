# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
data = pd.read_csv('./singlejab.csv',index_col=0)

# %%
data.head(20)
# Out:
#     acc_X  acc_Y  acc_Z  gyro_X  gyro_Y  gyro_Z        acc
# 0    0.71   0.31   0.56  -50.43    1.77    4.39   0.955929
# 1    0.71   0.30   0.56  -48.32    1.28    4.15   0.952733
# 2    0.71   0.30   0.57  -46.65    2.41    4.15   0.958645
# 3    0.71   0.31   0.57  -45.37    2.26    5.12   0.961821
# 4    0.72   0.31   0.56  -43.72    4.12    4.73   0.963379
# 5    0.72   0.32   0.56  -42.35    4.85    5.37   0.966644
# 6    0.72   0.33   0.57  -40.98    6.83    5.55   0.975807
# 7    0.72   0.34   0.57  -39.24    9.39    5.52   0.979234
# 8    0.69   0.34   0.58  -37.71    9.36    7.04   0.963379
# 9    0.70   0.34   0.58  -35.09   11.13    9.02   0.970567
# 10  70.40   0.49   0.92   -0.27    1.95    1.52  70.407716
# 11   0.40   0.49   0.92   -0.30    1.55    2.04   1.116468
# 12   0.40   0.48   0.92   -0.24    1.07    2.74   1.112115
# 13   0.40   0.48   0.93    0.24    0.52    3.14   1.120402
# 14   0.40   0.48   0.92    0.61   -0.03    3.60   1.112115
# ...

# %%
data = data.loc[50:400]

# %%
plt.figure(figsize=(30,10))
sns.lineplot(data=[data['acc_X'],data['acc_Y'],data['acc_Z'],data['acc']])
# Out:
# <AxesSubplot:>

# %%
def animate(*vargs):
    ser = serial.Serial('/dev/ttyUSB0',460800)
    time.sleep(10)
    for _ in range(100):
        line=ser.readline()
        if len(line):
            print(line) 
        time.sleep(0.001)
    i=0
    while 1:
        line=ser.readline()
        data = line.decode()
        [aX,aY,aZ,gX,gY,gZ]=data.split(",")
        timestamp.append(i)
        acc_X.append(aX)
        acc_Y.append(aY)
        acc_Z.append(aZ) 
        gyro_X.append(gX)
        gyro_Y.append(gY)
        gyro_Z.append(gZ) 
        #ax1.clear()
        ax1.plot(timestamp,acc_X)
        #ax2.clear()
        ax2.plot(timestamp,acc_Y)
        #ax3.clear()
        ax3.plot(timestamp,acc_Z)
        #ax4.clear()
        ax4.plot(timestamp,gyro_X)
        #ax5.clear()
        ax5.plot(timestamp,gyro_Y)
        #ax6.clear()
        ax6.plot(timestamp,gyro_Z)
        
        time.sleep(0.001)

# %%
ani = anime.FuncAnimation(fig,animate,interval=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9839/3636253139.py in <module>
# ----> 1 ani = anime.FuncAnimation(fig,animate,interval=1)
#
# NameError: name 'anime' is not defined

# %%
plt.show()

# %%
l=map(int,['1','2'])

# %%
for x in l:
    print(x)
# Out:
# 1
# 2

# %%
idle = pd.read_csv('./idle.csv',index_col=0)

# %%
idle.head()
# Out:
#    acc_X  acc_Y  acc_Z  gyro_X  gyro_Y  gyro_Z       acc
# 0   0.65   0.29   0.69   25.88 -105.76   11.13  0.991312
# 1   0.65   0.30   0.68   25.91 -102.26   10.34  0.987370
# 2   0.65   0.31   0.67   25.82  -99.51   10.09  0.983616
# 3   0.65   0.31   0.67   25.27  -97.13   10.09  0.983616
# 4   0.65   0.33   0.66   24.45  -95.18   10.46  0.983362

# %%
plt.figure(figsize=(30,10))
sns.lineplot(data=[idle['acc_X'],idle['acc_Y'],idle['acc_Z'],idle['acc']])
# Out:
# <AxesSubplot:>

# %%
jabst=pd.read_csv('./jabstop.csv',index_col=0)

# %%
jabst = jabst.loc[50:400]

# %%
plt.figure(figsize=(30,10))
sns.lineplot(data=[jabst['acc_X'],jabst['acc_Y'],jabst['acc_Z'],jabst['acc']])
# Out:
# <AxesSubplot:>
